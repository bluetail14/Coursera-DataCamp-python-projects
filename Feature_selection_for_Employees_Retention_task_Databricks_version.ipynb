# %% [markdown]
# # Can you help reduce employee turnover?
#
# ## 📖 Background
# You work for the human resource department of a large corporation. The Board is worried about the relatively high turnover, and your team must look into ways to reduce the number of employees leaving the company.
#
# The team needs to understand better the situation, which employees are more likely to leave, and why. Once it is clear what variables impact employee churn, you can present your findings along with your ideas on how to attack the problem.

# %% [markdown]
# ## 💾 The data
# The department has assembled data on almost 10,000 employees. The team used information from exit interviews, performance reviews, and employee records.
#
# - "department" - the department the employee belongs to.
# - "promoted" - 1 if the employee was promoted in the previous 24 months, 0 otherwise.
# - "review" - the composite score the employee received in their last evaluation.
# - "projects" - how many projects the employee is involved in.
# - "salary" - for confidentiality reasons, salary comes in three tiers: low, medium, high.
# - "tenure" - how many years the employee has been at the company.
# - "satisfaction" - a measure of employee satisfaction from surveys.
# - "avg_hrs_month" - the average hours the employee worked in a month.
# - "left" - "yes" if the employee ended up leaving, "no" otherwise.

# %% [markdown]
# ## Create a report that covers the following:
#
# 1. Which department has the highest employee turnover? Which one has the lowest?
# 2. Investigate which variables seem to be better predictors of employee departure.
# 3. What recommendations would you make regarding ways to reduce employee turnover?

# %% [markdown]
# ## Report content:
#
# -
# 1. Preliminary remarks and data exploration.
# 2. Feature design and exploration.
# 3. Modelling and feature selection.
# 4. Recommendations to reduce employee turnover.

# %% [markdown]
# ## This solution uses in-built Panda functionality which is enough for this dataset. PySpark  should be used with larger datasets where more than one user is working on a model. Another version of my solution is modular.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>wasbs://training@dbtrainukwest.blob.core.windows.net/</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %pip install imbalanced-learn
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
# Requirement already satisfied: threadpoolctl&gt;=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from imbalanced-learn) (2.1.0)
# Requirement already satisfied: numpy&gt;=1.14.6 in /databricks/python3/lib/python3.8/site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: joblib&gt;=0.11 in /databricks/python3/lib/python3.8/site-packages (from imbalanced-learn) (1.0.1)
# Collecting scikit-learn&gt;=1.0.1
#   Downloading scikit_learn-1.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Requirement already satisfied: scipy&gt;=1.1.0 in /databricks/python3/lib/python3.8/site-packages (from imbalanced-learn) (1.6.2)
# Installing collected packages: scikit-learn, imbalanced-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Not uninstalling scikit-learn at /databricks/python3/lib/python3.8/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-a0478f27-17b2-4d94-aec6-7ca63dca5d59
#     Can&#39;t uninstall &#39;scikit-learn&#39;. No files were found to uninstall.
# Successfully installed imbalanced-learn-0.9.0 scikit-learn-1.0.2
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-a0478f27-17b2-4d94-aec6-7ca63dca5d59/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# </div>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import plot_confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import f1_score,roc_curve
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * FROM adsda.employee_churn_data LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>promoted</th><th>review</th><th>projects</th><th>salary</th><th>tenure</th><th>satisfaction</th><th>bonus</th><th>avg_hrs_month</th><th>left</th></tr></thead><tbody><tr><td>operations</td><td>0</td><td>0.5775686596355698</td><td>3</td><td>low</td><td>5.0</td><td>0.6267589740293295</td><td>0</td><td>180.8660696668475</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.7518996607137884</td><td>3</td><td>medium</td><td>6.0</td><td>0.4436789547574034</td><td>0</td><td>182.7081489616225</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.7225484486077993</td><td>3</td><td>medium</td><td>6.0</td><td>0.4468232240377964</td><td>0</td><td>184.4160840365652</td><td>no</td></tr><tr><td>logistics</td><td>0</td><td>0.6751583086657402</td><td>4</td><td>high</td><td>8.0</td><td>0.4401387461171622</td><td>0</td><td>188.7075447757313</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.676203174778892</td><td>3</td><td>high</td><td>5.0</td><td>0.5776074456916579</td><td>1</td><td>179.82108327312108</td><td>no</td></tr><tr><td>IT</td><td>0</td><td>0.6832063469509659</td><td>2</td><td>medium</td><td>5.0</td><td>0.5652518631559001</td><td>1</td><td>178.8418791506508</td><td>no</td></tr><tr><td>admin</td><td>0</td><td>0.6201580151095236</td><td>4</td><td>high</td><td>5.0</td><td>0.6869511701465508</td><td>0</td><td>181.14295615536423</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.4995672619674808</td><td>4</td><td>medium</td><td>7.0</td><td>0.720451118181815</td><td>1</td><td>184.97753752486025</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.652817953302604</td><td>4</td><td>low</td><td>6.0</td><td>0.6786959372102828</td><td>0</td><td>183.6557898051497</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.642030504394421</td><td>3</td><td>medium</td><td>6.0</td><td>0.6233650093739659</td><td>0</td><td>181.8509998905145</td><td>no</td></tr></tbody></table></div>

# %% [markdown]
# ### 1. Preliminary remarks and data exploration.
#
# Prior to technical analysis, tt is a good idea to gain the 'domain knowledge' e.g. by speaking the HR deparment about what they consider to be the main causes of employee departures. This could aid in selecting important  features.

# %%
# convert the table to a dataframe
df = spark.table("adsda.employee_churn_data").toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Understand your variables
variables = pd.DataFrame(columns=['Variable','Number of unique values','Number of nulls','Values'])

for i, var in enumerate(df.columns):
    variables.loc[i] = [var, df[var].nunique(),df[var].isnull().sum(), df[var].unique().tolist()]
variables
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Variable</th>
#       <th>Number of unique values</th>
#       <th>Number of nulls</th>
#       <th>Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>department</td>
#       <td>10</td>
#       <td>0</td>
#       <td>[operations, support, logistics, sales, IT, ad...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>promoted</td>
#       <td>2</td>
#       <td>0</td>
#       <td>[0, 1]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>review</td>
#       <td>9540</td>
#       <td>0</td>
#       <td>[0.5775686596355698, 0.7518996607137884, 0.722...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>projects</td>
#       <td>4</td>
#       <td>0</td>
#       <td>[3, 4, 2, 5]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>salary</td>
#       <td>3</td>
#       <td>0</td>
#       <td>[low, medium, high]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>tenure</td>
#       <td>11</td>
#       <td>0</td>
#       <td>[5.0, 6.0, 8.0, 7.0, 4.0, 3.0, 2.0, 9.0, 10.0,...</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>satisfaction</td>
#       <td>9540</td>
#       <td>0</td>
#       <td>[0.6267589740293295, 0.4436789547574034, 0.446...</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>bonus</td>
#       <td>2</td>
#       <td>0</td>
#       <td>[0, 1]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>avg_hrs_month</td>
#       <td>9540</td>
#       <td>0</td>
#       <td>[180.8660696668475, 182.7081489616225, 184.416...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>left</td>
#       <td>2</td>
#       <td>0</td>
#       <td>[no, yes]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#display(spark.sql("SELECT * FROM adsda.employee_churn_data").summary())
df.describe(include='all')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>department</th>
#       <th>promoted</th>
#       <th>review</th>
#       <th>projects</th>
#       <th>salary</th>
#       <th>tenure</th>
#       <th>satisfaction</th>
#       <th>bonus</th>
#       <th>avg_hrs_month</th>
#       <th>left</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>9540</td>
#       <td>9540.000000</td>
#       <td>9540.000000</td>
#       <td>9540.000000</td>
#       <td>9540</td>
#       <td>9540.000000</td>
#       <td>9540.000000</td>
#       <td>9540.000000</td>
#       <td>9540.000000</td>
#       <td>9540</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>sales</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>medium</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>1883</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6611</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6756</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>NaN</td>
#       <td>0.030294</td>
#       <td>0.651826</td>
#       <td>3.274843</td>
#       <td>NaN</td>
#       <td>6.556184</td>
#       <td>0.504645</td>
#       <td>0.212055</td>
#       <td>184.661571</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>NaN</td>
#       <td>0.171403</td>
#       <td>0.085307</td>
#       <td>0.579136</td>
#       <td>NaN</td>
#       <td>1.415432</td>
#       <td>0.158555</td>
#       <td>0.408785</td>
#       <td>4.144831</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>NaN</td>
#       <td>0.000000</td>
#       <td>0.310000</td>
#       <td>2.000000</td>
#       <td>NaN</td>
#       <td>2.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>171.374060</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>NaN</td>
#       <td>0.000000</td>
#       <td>0.592884</td>
#       <td>3.000000</td>
#       <td>NaN</td>
#       <td>5.000000</td>
#       <td>0.386801</td>
#       <td>0.000000</td>
#       <td>181.472085</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>NaN</td>
#       <td>0.000000</td>
#       <td>0.647456</td>
#       <td>3.000000</td>
#       <td>NaN</td>
#       <td>7.000000</td>
#       <td>0.500786</td>
#       <td>0.000000</td>
#       <td>184.628796</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>NaN</td>
#       <td>0.000000</td>
#       <td>0.708379</td>
#       <td>4.000000</td>
#       <td>NaN</td>
#       <td>8.000000</td>
#       <td>0.622607</td>
#       <td>0.000000</td>
#       <td>187.728708</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>NaN</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>5.000000</td>
#       <td>NaN</td>
#       <td>12.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>200.861656</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df['left'].value_counts()   # it is an inbalanced dataset with 30% of yes and 70% of no.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: no     6756
# yes    2784
# Name: left, dtype: int64</div>

# %%
# %sql
SELECT left, count(*) AS Count_employee_departures
FROM adsda.employee_churn_data  GROUP BY left
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>left</th><th>Count_employee_departures</th></tr></thead><tbody><tr><td>no</td><td>6756</td></tr><tr><td>yes</td><td>2784</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM adsda.employee_churn_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>promoted</th><th>review</th><th>projects</th><th>salary</th><th>tenure</th><th>satisfaction</th><th>bonus</th><th>avg_hrs_month</th><th>left</th></tr></thead><tbody><tr><td>operations</td><td>0</td><td>0.5775686596355698</td><td>3</td><td>low</td><td>5.0</td><td>0.6267589740293295</td><td>0</td><td>180.8660696668475</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.7518996607137884</td><td>3</td><td>medium</td><td>6.0</td><td>0.4436789547574034</td><td>0</td><td>182.7081489616225</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.7225484486077993</td><td>3</td><td>medium</td><td>6.0</td><td>0.4468232240377964</td><td>0</td><td>184.4160840365652</td><td>no</td></tr><tr><td>logistics</td><td>0</td><td>0.6751583086657402</td><td>4</td><td>high</td><td>8.0</td><td>0.4401387461171622</td><td>0</td><td>188.7075447757313</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.676203174778892</td><td>3</td><td>high</td><td>5.0</td><td>0.5776074456916579</td><td>1</td><td>179.82108327312108</td><td>no</td></tr><tr><td>IT</td><td>0</td><td>0.6832063469509659</td><td>2</td><td>medium</td><td>5.0</td><td>0.5652518631559001</td><td>1</td><td>178.8418791506508</td><td>no</td></tr><tr><td>admin</td><td>0</td><td>0.6201580151095236</td><td>4</td><td>high</td><td>5.0</td><td>0.6869511701465508</td><td>0</td><td>181.14295615536423</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.4995672619674808</td><td>4</td><td>medium</td><td>7.0</td><td>0.720451118181815</td><td>1</td><td>184.97753752486025</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.652817953302604</td><td>4</td><td>low</td><td>6.0</td><td>0.6786959372102828</td><td>0</td><td>183.6557898051497</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.642030504394421</td><td>3</td><td>medium</td><td>6.0</td><td>0.6233650093739659</td><td>0</td><td>181.8509998905145</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.5626754376858702</td><td>4</td><td>medium</td><td>5.0</td><td>0.5594676676578171</td><td>0</td><td>178.92719417309084</td><td>no</td></tr><tr><td>engineering</td><td>0</td><td>0.7991111029647973</td><td>3</td><td>medium</td><td>5.0</td><td>0.4325323607963424</td><td>1</td><td>180.77952738075683</td><td>no</td></tr><tr><td>marketing</td><td>0</td><td>0.6114193735102076</td><td>3</td><td>low</td><td>6.0</td><td>0.502041001444069</td><td>0</td><td>183.66668563156088</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.6471073891917132</td><td>3</td><td>medium</td><td>5.0</td><td>0.624035475650507</td><td>0</td><td>181.30567680708663</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.5674485434116767</td><td>3</td><td>medium</td><td>6.0</td><td>0.8452464576655928</td><td>0</td><td>181.75658430618995</td><td>no</td></tr><tr><td>finance</td><td>0</td><td>0.5826514153122677</td><td>3</td><td>medium</td><td>6.0</td><td>0.6080274074180824</td><td>0</td><td>184.0290110658382</td><td>no</td></tr><tr><td>IT</td><td>0</td><td>0.6796209222260405</td><td>4</td><td>low</td><td>6.0</td><td>0.4802449946817246</td><td>0</td><td>183.42378733872823</td><td>no</td></tr><tr><td>admin</td><td>0</td><td>0.4711184556686002</td><td>4</td><td>low</td><td>5.0</td><td>0.8874390222449627</td><td>0</td><td>180.44372431964084</td><td>no</td></tr><tr><td>engineering</td><td>0</td><td>0.6225236476627087</td><td>3</td><td>medium</td><td>6.0</td><td>0.6883371488025413</td><td>0</td><td>182.54884545902505</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.5296950068551335</td><td>3</td><td>medium</td><td>6.0</td><td>0.6828142013248505</td><td>1</td><td>184.1247600031577</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.6697767182375025</td><td>2</td><td>medium</td><td>7.0</td><td>0.5113506495685215</td><td>0</td><td>185.82707830673883</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.7500916300001673</td><td>2</td><td>mediu ...

# %%
# %sql

SELECT * FROM adsda.employee_churn_data LIMIT
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>promoted</th><th>review</th><th>projects</th><th>salary</th><th>tenure</th><th>satisfaction</th><th>bonus</th><th>avg_hrs_month</th><th>left</th></tr></thead><tbody><tr><td>operations</td><td>0</td><td>0.5775686596355698</td><td>3</td><td>low</td><td>5.0</td><td>0.6267589740293295</td><td>0</td><td>180.8660696668475</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.7518996607137884</td><td>3</td><td>medium</td><td>6.0</td><td>0.4436789547574034</td><td>0</td><td>182.7081489616225</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.7225484486077993</td><td>3</td><td>medium</td><td>6.0</td><td>0.4468232240377964</td><td>0</td><td>184.4160840365652</td><td>no</td></tr><tr><td>logistics</td><td>0</td><td>0.6751583086657402</td><td>4</td><td>high</td><td>8.0</td><td>0.4401387461171622</td><td>0</td><td>188.7075447757313</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.676203174778892</td><td>3</td><td>high</td><td>5.0</td><td>0.5776074456916579</td><td>1</td><td>179.82108327312108</td><td>no</td></tr><tr><td>IT</td><td>0</td><td>0.6832063469509659</td><td>2</td><td>medium</td><td>5.0</td><td>0.5652518631559001</td><td>1</td><td>178.8418791506508</td><td>no</td></tr><tr><td>admin</td><td>0</td><td>0.6201580151095236</td><td>4</td><td>high</td><td>5.0</td><td>0.6869511701465508</td><td>0</td><td>181.14295615536423</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.4995672619674808</td><td>4</td><td>medium</td><td>7.0</td><td>0.720451118181815</td><td>1</td><td>184.97753752486025</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.652817953302604</td><td>4</td><td>low</td><td>6.0</td><td>0.6786959372102828</td><td>0</td><td>183.6557898051497</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.642030504394421</td><td>3</td><td>medium</td><td>6.0</td><td>0.6233650093739659</td><td>0</td><td>181.8509998905145</td><td>no</td></tr><tr><td>support</td><td>0</td><td>0.5626754376858702</td><td>4</td><td>medium</td><td>5.0</td><td>0.5594676676578171</td><td>0</td><td>178.92719417309084</td><td>no</td></tr><tr><td>engineering</td><td>0</td><td>0.7991111029647973</td><td>3</td><td>medium</td><td>5.0</td><td>0.4325323607963424</td><td>1</td><td>180.77952738075683</td><td>no</td></tr><tr><td>marketing</td><td>0</td><td>0.6114193735102076</td><td>3</td><td>low</td><td>6.0</td><td>0.502041001444069</td><td>0</td><td>183.66668563156088</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.6471073891917132</td><td>3</td><td>medium</td><td>5.0</td><td>0.624035475650507</td><td>0</td><td>181.30567680708663</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.5674485434116767</td><td>3</td><td>medium</td><td>6.0</td><td>0.8452464576655928</td><td>0</td><td>181.75658430618995</td><td>no</td></tr><tr><td>finance</td><td>0</td><td>0.5826514153122677</td><td>3</td><td>medium</td><td>6.0</td><td>0.6080274074180824</td><td>0</td><td>184.0290110658382</td><td>no</td></tr><tr><td>IT</td><td>0</td><td>0.6796209222260405</td><td>4</td><td>low</td><td>6.0</td><td>0.4802449946817246</td><td>0</td><td>183.42378733872823</td><td>no</td></tr><tr><td>admin</td><td>0</td><td>0.4711184556686002</td><td>4</td><td>low</td><td>5.0</td><td>0.8874390222449627</td><td>0</td><td>180.44372431964084</td><td>no</td></tr><tr><td>engineering</td><td>0</td><td>0.6225236476627087</td><td>3</td><td>medium</td><td>6.0</td><td>0.6883371488025413</td><td>0</td><td>182.54884545902505</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.5296950068551335</td><td>3</td><td>medium</td><td>6.0</td><td>0.6828142013248505</td><td>1</td><td>184.1247600031577</td><td>no</td></tr><tr><td>sales</td><td>0</td><td>0.6697767182375025</td><td>2</td><td>medium</td><td>7.0</td><td>0.5113506495685215</td><td>0</td><td>185.82707830673883</td><td>no</td></tr><tr><td>operations</td><td>0</td><td>0.7500916300001673</td><td>2</td><td>mediu ...

# %%
# %sql
SELECT department, count(left) AS Total_departures

FROM adsda.employee_churn_data GROUP BY department 
ORDER BY Employee_departures_by_department DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>Employee_departures_by_department</th></tr></thead><tbody><tr><td>sales</td><td>1883</td></tr><tr><td>retail</td><td>1541</td></tr><tr><td>operations</td><td>1522</td></tr><tr><td>engineering</td><td>1516</td></tr><tr><td>marketing</td><td>802</td></tr><tr><td>support</td><td>735</td></tr><tr><td>admin</td><td>423</td></tr><tr><td>finance</td><td>402</td></tr><tr><td>logistics</td><td>360</td></tr><tr><td>IT</td><td>356</td></tr></tbody></table></div>

# %%
sns.set_style('white')
filter = df['left'] == 'yes'
g = sns.catplot(data=df[filter], kind='count', y='department', palette='magma_r',
            order=df[filter]['department'].value_counts(ascending=True).index)
g.fig.suptitle('Employee departures by department')
g.fig.subplots_adjust(top=0.9)

#abs_values = df[filter]['department'].value_counts(ascending=True)
#g.bar_label(container=g.containers[0], labels=abs_values)
for ax in g.axes.flat:
    ax.bar_label(ax.containers[0], fontsize=12)
    ax.margins(x=0.1)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# #####As we can see from the bar chart, the highest employee turnover is at the sales department followed by retail, engineering and operations. On the other end of the scale are finance, IT, logistics and admin with the lowest employee turnover.

# %% [markdown]
# ### 2. Feature design and exploration.

# %% [markdown]
# The dataset has mixed data with both numerical and categorical values. Some of the features, bonus and promoted, are binomial, while department and salary are ordinal. There are no missing vales and requires scaling (the larger values for average hours per month). The scatterplots show that two pairs of features, average hours per month and tenure, and review and satisfaction, are strongly correlated with each other. The numeric variables  are normally distributioned

# %%
cat_cols = ['department','promoted','salary','bonus', 'left']
df[cat_cols] = df[cat_cols].astype('category')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# One-hot encoding of the categorical features  
df = pd.get_dummies(df, columns=['department'])
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: Index([&#39;promoted&#39;, &#39;review&#39;, &#39;projects&#39;, &#39;salary&#39;, &#39;tenure&#39;, &#39;satisfaction&#39;,
#        &#39;bonus&#39;, &#39;avg_hrs_month&#39;, &#39;left&#39;, &#39;department_IT&#39;, &#39;department_admin&#39;,
#        &#39;department_engineering&#39;, &#39;department_finance&#39;, &#39;department_logistics&#39;,
#        &#39;department_marketing&#39;, &#39;department_operations&#39;, &#39;department_retail&#39;,
#        &#39;department_sales&#39;, &#39;department_support&#39;],
#       dtype=&#39;object&#39;)</div>

# %%
df.columns = df.columns.str.replace('department_','')

df1 = df.loc[:,df.columns!='left']
df2 = df.loc[:,df.columns=='left']
df = pd.concat([df1, df2], 1)
df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>promoted</th>
#       <th>review</th>
#       <th>projects</th>
#       <th>salary</th>
#       <th>tenure</th>
#       <th>satisfaction</th>
#       <th>bonus</th>
#       <th>avg_hrs_month</th>
#       <th>IT</th>
#       <th>admin</th>
#       <th>engineering</th>
#       <th>finance</th>
#       <th>logistics</th>
#       <th>marketing</th>
#       <th>operations</th>
#       <th>retail</th>
#       <th>sales</th>
#       <th>support</th>
#       <th>left</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0.577569</td>
#       <td>3</td>
#       <td>low</td>
#       <td>5.0</td>
#       <td>0.626759</td>
#       <td>0</td>
#       <td>180.866070</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0.751900</td>
#       <td>3</td>
#       <td>medium</td>
#       <td>6.0</td>
#       <td>0.443679</td>
#       <td>0</td>
#       <td>182.708149</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0.722548</td>
#       <td>3</td>
#       <td>medium</td>
#       <td>6.0</td>
#       <td>0.446823</td>
#       <td>0</td>
#       <td>184.416084</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>0.675158</td>
#       <td>4</td>
#       <td>high</td>
#       <td>8.0</td>
#       <td>0.440139</td>
#       <td>0</td>
#       <td>188.707545</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>0.676203</td>
#       <td>3</td>
#       <td>high</td>
#       <td>5.0</td>
#       <td>0.577607</td>
#       <td>1</td>
#       <td>179.821083</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>no</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Ordinal encode of salary and left 
oe = OrdinalEncoder()

df[["salary","left"]] = oe.fit_transform(df[["salary", "left"]])
#df["salary"] = df["salary"].replace(0,3)
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>promoted</th>
#       <th>review</th>
#       <th>projects</th>
#       <th>salary</th>
#       <th>tenure</th>
#       <th>satisfaction</th>
#       <th>bonus</th>
#       <th>avg_hrs_month</th>
#       <th>IT</th>
#       <th>admin</th>
#       <th>engineering</th>
#       <th>finance</th>
#       <th>logistics</th>
#       <th>marketing</th>
#       <th>operations</th>
#       <th>retail</th>
#       <th>sales</th>
#       <th>support</th>
#       <th>left</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0.577569</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>0.626759</td>
#       <td>0</td>
#       <td>180.866070</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0.751900</td>
#       <td>3</td>
#       <td>2.0</td>
#       <td>6.0</td>
#       <td>0.443679</td>
#       <td>0</td>
#       <td>182.708149</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0.722548</td>
#       <td>3</td>
#       <td>2.0</td>
#       <td>6.0</td>
#       <td>0.446823</td>
#       <td>0</td>
#       <td>184.416084</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>0.675158</td>
#       <td>4</td>
#       <td>0.0</td>
#       <td>8.0</td>
#       <td>0.440139</td>
#       <td>0</td>
#       <td>188.707545</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>0.676203</td>
#       <td>3</td>
#       <td>0.0</td>
#       <td>5.0</td>
#       <td>0.577607</td>
#       <td>1</td>
#       <td>179.821083</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9535</th>
#       <td>0</td>
#       <td>0.610988</td>
#       <td>4</td>
#       <td>2.0</td>
#       <td>8.0</td>
#       <td>0.543641</td>
#       <td>0</td>
#       <td>188.155738</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9536</th>
#       <td>0</td>
#       <td>0.746887</td>
#       <td>3</td>
#       <td>2.0</td>
#       <td>8.0</td>
#       <td>0.549048</td>
#       <td>0</td>
#       <td>188.176164</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9537</th>
#       <td>0</td>
#       <td>0.557980</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>7.0</td>
#       <td>0.705425</td>
#       <td>0</td>
#       <td>186.531008</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9538</th>
#       <td>0</td>
#       <td>0.584446</td>
#       <td>4</td>
#       <td>2.0</td>
#       <td>8.0</td>
#       <td>0.607287</td>
#       <td>1</td>
#       <td>187.641370</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9539</th>
#       <td>0</td>
#       <td>0.626373</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>7.0</td>
#       <td>0.706455</td>
#       <td>1</td>
#       <td>185.920934</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>9540 rows × 19 columns</p>
# </div>

# %%
df_dept = df.iloc[:, -10:]
df_dept.head(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>admin</th>
#       <th>engineering</th>
#       <th>finance</th>
#       <th>logistics</th>
#       <th>marketing</th>
#       <th>operations</th>
#       <th>retail</th>
#       <th>sales</th>
#       <th>support</th>
#       <th>left</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# select the continious and ordinal columns for Spearmens' 
spearmans_cols = ['review','satisfaction', 'avg_hrs_month', 'tenure', 'projects','salary', 'left']
df_sp = df[spearmans_cols]
df_sp

sc = StandardScaler()
df_scaled = pd.DataFrame(sc.fit_transform(df_sp), index=df_sp.index, columns=df_sp.columns)
df_scaled
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review</th>
#       <th>satisfaction</th>
#       <th>avg_hrs_month</th>
#       <th>tenure</th>
#       <th>projects</th>
#       <th>salary</th>
#       <th>left</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.870524</td>
#       <td>0.770211</td>
#       <td>-0.915767</td>
#       <td>-1.099499</td>
#       <td>-0.474599</td>
#       <td>-0.700746</td>
#       <td>-0.641933</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.173161</td>
#       <td>-0.384527</td>
#       <td>-0.471316</td>
#       <td>-0.392964</td>
#       <td>-0.474599</td>
#       <td>0.619641</td>
#       <td>-0.641933</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.829076</td>
#       <td>-0.364695</td>
#       <td>-0.059230</td>
#       <td>-0.392964</td>
#       <td>-0.474599</td>
#       <td>0.619641</td>
#       <td>-0.641933</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.273521</td>
#       <td>-0.406856</td>
#       <td>0.976200</td>
#       <td>1.020106</td>
#       <td>1.252203</td>
#       <td>-2.021133</td>
#       <td>-0.641933</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.285770</td>
#       <td>0.460198</td>
#       <td>-1.167898</td>
#       <td>-1.099499</td>
#       <td>-0.474599</td>
#       <td>-2.021133</td>
#       <td>-0.641933</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9535</th>
#       <td>-0.478744</td>
#       <td>0.245959</td>
#       <td>0.843062</td>
#       <td>1.020106</td>
#       <td>1.252203</td>
#       <td>0.619641</td>
#       <td>1.557795</td>
#     </tr>
#     <tr>
#       <th>9536</th>
#       <td>1.114402</td>
#       <td>0.280068</td>
#       <td>0.847991</td>
#       <td>1.020106</td>
#       <td>-0.474599</td>
#       <td>0.619641</td>
#       <td>1.557795</td>
#     </tr>
#     <tr>
#       <th>9537</th>
#       <td>-1.100166</td>
#       <td>1.266378</td>
#       <td>0.451052</td>
#       <td>0.313571</td>
#       <td>-0.474599</td>
#       <td>-0.700746</td>
#       <td>1.557795</td>
#     </tr>
#     <tr>
#       <th>9538</th>
#       <td>-0.789903</td>
#       <td>0.647395</td>
#       <td>0.718957</td>
#       <td>1.020106</td>
#       <td>1.252203</td>
#       <td>0.619641</td>
#       <td>1.557795</td>
#     </tr>
#     <tr>
#       <th>9539</th>
#       <td>-0.298386</td>
#       <td>1.272875</td>
#       <td>0.303855</td>
#       <td>0.313571</td>
#       <td>-0.474599</td>
#       <td>-0.700746</td>
#       <td>1.557795</td>
#     </tr>
#   </tbody>
# </table>
# <p>9540 rows × 7 columns</p>
# </div>

# %% [markdown]
# Lets investigate the relationships between the features.

# %%
corrmat = df_scaled.corr(method ='spearman')
top_corr_features = corrmat.index
plt.figure(figsize=(12,6))
#plot heat map
g=sns.heatmap(df_scaled[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# Spearman's correlation is good for ordinal data. The correlation matrix shows that satisfaction from the job and the number of projects an employee's involved indicate a negative relationship with employee departure, i.e. a satisfied employee busy with many projects is more likely to stay. However, high review scores seem to significantly contribute to the number of depatures with the corr coef = 0.3. Meanwhile, satisfaction is negatively correlated with performance reviews, suggesting that higher scores in reviews area associated with lower levels of satisfaction. Average hours of work per month are almost perfectly postively correlated, suggesting that they're interchangble as features.

# %%
X_features = df.drop('left', axis=1)
y_target = df[['left']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### 3. Modelling and feature selection.

# %% [markdown]
# Distance based methods such as KNN,  Decision trees and their ensemble, Random Forest are better at handing mixed data. Tree-based models are good at capturing non-linear relationships between the categorical features and the target, and they tend to handle feature collinearity better.
# I will be using two methods for feature selection described here, <https://scikit-learn.org/stable/modules/feature_selection.html>
#     - Univariate feature selection with the mutual information(M()) classification function,
#     - Tree-based feature importances with the SelectFromModel meta-transformer
#
# MI measures the degree of relatedness between data sets, or in other words, it  quantifies the extent to which a feature (e.g. the review score) determines the employee's departure.

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif

fs = SelectKBest(score_func=mutual_info_classif, k=5).fit(X_features, y_target)
fs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/.ephemeral_nfs/envs/pythonEnv-a0478f27-17b2-4d94-aec6-7ca63dca5d59/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Out[15]: SelectKBest(k=5, score_func=&lt;function mutual_info_classif at 0x7f3cbaa8e160&gt;)</div>

# %%
#projects and tenure can be ordinarily encoded. Num_cols include continious  data while cat_cols include categorical/binomial.

num_cols = ['review','satisfaction', 'avg_hrs_month', 'tenure', 'projects']
cat_cols = ['salary','department','bonus','promoted','left']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(fs.scores_)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[0.         0.06208892 0.         0.00292696 0.03948201 0.00082961
#  0.0029952  0.05998497 0.00277824 0.00418362 0.         0.
#  0.         0.         0.         0.         0.         0.00786566]
# </div>

# %%
f_importance = fs.scores_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
idx = np.argsort(f_importance)
idx
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: array([ 0, 15,  2, 14, 13, 12, 11, 16, 10,  5,  8,  3,  6,  9, 17,  4,  7,
#         1])</div>

# %%
cols = X_features.columns.values.tolist()

arr_f = np.array(cols)[idx]
arr_f
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: array([&#39;promoted&#39;, &#39;retail&#39;, &#39;projects&#39;, &#39;operations&#39;, &#39;marketing&#39;,
#        &#39;logistics&#39;, &#39;finance&#39;, &#39;sales&#39;, &#39;engineering&#39;, &#39;satisfaction&#39;,
#        &#39;IT&#39;, &#39;salary&#39;, &#39;bonus&#39;, &#39;admin&#39;, &#39;support&#39;, &#39;tenure&#39;,
#        &#39;avg_hrs_month&#39;, &#39;review&#39;], dtype=&#39;&lt;U13&#39;)</div>

# %%
plt.barh(arr_f, f_importance[idx])
plt.suptitle('Features ranked by mutual infomation values', fontsize=14)
plt.show()

# %% [markdown]
# #####From the above bar chart, Review, Average hours per month and tenure are the three top features influencing  employee departure.

# %% [markdown]
# I will use two tree-based models, Random ForestClassifier() and GradientBoostingClassifier() for feature selection.
#
# A suitable metric for this binary classification problem is the f1 score, which takes an account both precision and recall for the cases of employee departures. The recall metric focuses on  what percentage of all cases of employee departures  the model has predicted correctly  while precision measures what percentage of all predicted employee departures are true employee departures.
#
# In the below analysis, the number of the correct predictions for employee departures (aka true positives), is shown in the bottom right corner of the confusion matrix.
# by using the RandomForest and GradientBoosting classifiers.

# %%
X = df[['promoted', 'review', 'projects', 'salary', 'tenure', 'satisfaction',
       'bonus', 'avg_hrs_month']]
                          
y = df['left']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ######I am going to attempt to improve predictions further by balancing the two classes in the dataset using undersampling. With oversampling, the minority class will be the same size as the majority class, achieving the highest F1_score =0.93 for the employee departures in the dataset.

# %%
from imblearn.over_sampling import RandomOverSampler
oversample_1 = RandomOverSampler(sampling_strategy='minority')

X_over, y_over = oversample_1.fit_resample(X, y)
print(y_over.value_counts())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.0    6756
# 1.0    6756
# Name: left, dtype: int64
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over)

rf = RandomForestClassifier(random_state=8)

rf1 =rf.fit(X_train, y_train)

pred1 = rf1.predict(X_test)
print(confusion_matrix(y_test, rf.predict(X_test)))

plot_confusion_matrix(rf, X_test, y_test)  
plt.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[[1554  166]
#  [  48 1610]]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-a0478f27-17b2-4d94-aec6-7ca63dca5d59/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# </div>

# %%
print(classification_report(y_test, pred1))  #0.91, 0.97
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">              precision    recall  f1-score   support
#
#          0.0       0.97      0.90      0.94      1720
#          1.0       0.91      0.97      0.94      1658
#
#     accuracy                           0.94      3378
#    macro avg       0.94      0.94      0.94      3378
# weighted avg       0.94      0.94      0.94      3378
#
# </div>

# %%
#%pip install imbalanced-learn
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Random forest classification

# %%
# Generate the validation and test subsets using the balanced data.
over_df = pd.merge(X_over, y_over, left_index=True, right_index=True)
over_df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>promoted</th>
#       <th>review</th>
#       <th>projects</th>
#       <th>salary</th>
#       <th>tenure</th>
#       <th>satisfaction</th>
#       <th>bonus</th>
#       <th>avg_hrs_month</th>
#       <th>left</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0.577569</td>
#       <td>3</td>
#       <td>1.0</td>
#       <td>5.0</td>
#       <td>0.626759</td>
#       <td>0</td>
#       <td>180.866070</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0.751900</td>
#       <td>3</td>
#       <td>2.0</td>
#       <td>6.0</td>
#       <td>0.443679</td>
#       <td>0</td>
#       <td>182.708149</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0.722548</td>
#       <td>3</td>
#       <td>2.0</td>
#       <td>6.0</td>
#       <td>0.446823</td>
#       <td>0</td>
#       <td>184.416084</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>0.675158</td>
#       <td>4</td>
#       <td>0.0</td>
#       <td>8.0</td>
#       <td>0.440139</td>
#       <td>0</td>
#       <td>188.707545</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>0.676203</td>
#       <td>3</td>
#       <td>0.0</td>
#       <td>5.0</td>
#       <td>0.577607</td>
#       <td>1</td>
#       <td>179.821083</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cross_val_df, test_df = train_test_split(over_df, train_size=0.80, test_size=0.20, random_state=32)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rfc = RandomForestClassifier(random_state=32)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
parameter_grid = {
  'max_depth':[10, 20, 30, 40], 
  'n_estimators':[ 60, 70, 80, 100, 120]
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
grid_search1 = GridSearchCV(estimator=rfc, cv=5, param_grid=parameter_grid, scoring='f1').fit(cross_val_df.drop("left", axis=1), cross_val_df["left"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
grid_search1.best_params_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[72]: {&#39;max_depth&#39;: 30, &#39;n_estimators&#39;: 70}</div>

# %%
grid_search1.best_score_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[73]: 0.9204561458000855</div>

# %%
f1_score(
  test_df["left"], 
  grid_search1.predict(test_df.drop("left", axis=1))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: 0.9313196691837468</div>

# %%
rfc = RandomForestClassifier( n_estimators = 70, max_depth=30, random_state = 32).fit(cross_val_df.drop("left", axis=1), cross_val_df["left"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rfc.feature_importances_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: array([0.00363693, 0.27704476, 0.01975583, 0.01562356, 0.09470436,
#        0.28863573, 0.00930342, 0.2912954 ])</div>

# %%
lst = cross_val_df.drop("left", axis=1).columns.values.tolist()
feature_names = [f"{i}" for i in lst]

std = np.std([tree.feature_importances_ for tree in rfc.estimators_], axis=0)

importances = rfc.feature_importances_
forest_importances = pd.Series(importances, index=feature_names)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fig, ax = plt.subplots()
forest_importances.sort_values(ascending=False).plot.bar(yerr = -np.sort(-std), ax=ax)
ax.set_title("Feature importances using MDI: Random Forest")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# #####The three most important features are average hours per month, review and satisfaction. We should note that Tenure and  average hours can be interchangeable.

# %% [markdown]
# ###GradientBoostingClassifier()

# %%
grad_boost = GradientBoostingClassifier()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
parameter_grid = {   
    'max_depth':[8,10,12],
    'n_estimators':[150, 180, 200],
    'learning_rate':[0.01, 0.9, 1, 1.1]
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
grid_search2 = GridSearchCV(estimator = grad_boost,  cv = 5, param_grid = parameter_grid, scoring="f1").fit(cross_val_df.drop("left", axis=1), cross_val_df["left"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
grid_search2.best_params_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: {&#39;learning_rate&#39;: 1, &#39;max_depth&#39;: 12, &#39;n_estimators&#39;: 180}</div>

# %%
f1_score(
  test_df["left"], 
  grid_search2.predict(test_df.drop("left", axis=1))
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: 0.9269703543022415</div>

# %%
gbc = GradientBoostingClassifier(max_depth= 12, n_estimators = 180, learning_rate= 1, random_state = 32).fit(cross_val_df.drop("left", axis=1), cross_val_df["left"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gbc.feature_importances_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[77]: array([0.00310416, 0.28011076, 0.01352585, 0.01577338, 0.0026338 ,
#        0.30287202, 0.01048353, 0.3714965 ])</div>

# %%
importances = gbc.feature_importances_
forest_importances = pd.Series(importances, index=feature_names)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fig, ax = plt.subplots()
forest_importances.sort_values(ascending=False).plot.bar( ax=ax)
ax.set_title("Feature importances using MDI: GradientBoosting")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# #####The top three most important features are review, average hours per month and satisfaction.

# %% [markdown]
# ###  4. Recommendations to reduce the employee turnover.

# %% [markdown]
# #####Using several modelling methods, we noted that reviews, average hours per month, tenure and job satisfaction are the most important variables to influence employee departure. While an employee's longer average hours and the duration of stay with the company are associated more with employee retainment, an employee's high review scores are a strong indicator of employee departure. Although this may seem  counterintuitive at first, one of the aspects of a performance review is that an employee's targets get increased putting more pressure on an employee to meet their goals. Indeed,  we can observe that employee satisfaction is negatively correlated with performance reviews, and employee turnover is the highest within the sales and retail departments. It would be useful to evaluate the reviews to see if teh questions are biased towards a negative correlation.
#
# #####Management needs to pay closer attention to the four departments with the highest employee turnover (sales, retail, engineering and operations). If the data for the satisfaction scores is derived exclusively from exit surveys, it can be a leaked variable and not useful for the current analysis. However, if not, organisational behaviour practices that find ways to boost job satisfaction is key to employee retainment. Other factors being intersting and challenging work, appreciation from peers and superiors, and satisfactory compensation.
